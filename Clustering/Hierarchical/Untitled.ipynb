# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import datetime as dt

import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import cut_tree

# %%
# Read and Understand Data
# Clean Data
# Prepare data for modelling
# Modelling
# Business Recommendation

# %%
# read the dataset
retail_df = pd.read_csv("Online_Retail.csv", sep=",", encoding="ISO-8859-1", header=0)
retail_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  01-12-2010 08:26       2.55     17850.0  United Kingdom
# 1  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 2  01-12-2010 08:26       2.75     17850.0  United Kingdom
# 3  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 4  01-12-2010 08:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ### Clean Data

# %%
# missing values
round(100*(retail_df.isnull().sum())/len(retail_df), 2)
# Out:
# InvoiceNo       0.00
# StockCode       0.00
# Description     0.27
# Quantity        0.00
# InvoiceDate     0.00
# UnitPrice       0.00
# CustomerID     24.93
# Country         0.00
# dtype: float64

# %%
# drop all rows having missing values
retail_df = retail_df.dropna()
retail_df.shape
# Out:
# (406829, 8)

# %% [markdown]
# ### Data Preparation for Modelling

# %%
#R - Recency
#F - Frequency
#M - Monetary
# Cust_id Recency Frequency Monetary

# %%
retail_df['amount'] = retail_df.Quantity * retail_df.UnitPrice

# %%
grouped_df = retail_df.groupby(['CustomerID'])['amount'].sum()
grouped_df =  grouped_df.reset_index()

# %%
grouped_df.head()
# Out:
#    CustomerID   amount
# 0     12346.0     0.00
# 1     12347.0  4310.00
# 2     12348.0  1797.24
# 3     12349.0  1757.55
# 4     12350.0   334.40

# %%
frequency = retail_df.groupby(['CustomerID'])['InvoiceNo'].count()

# %%
frequency = frequency.reset_index()

# %%
frequency.head()
# Out:
#    CustomerID  InvoiceNo
# 0     12346.0          2
# 1     12347.0        182
# 2     12348.0         31
# 3     12349.0         73
# 4     12350.0         17

# %%
frequency.columns = ['CustomerID', 'frequency']

# %%
frequency.head()
# Out:
#    CustomerID  frequency
# 0     12346.0          2
# 1     12347.0        182
# 2     12348.0         31
# 3     12349.0         73
# 4     12350.0         17

# %%
grouped_df = pd.merge(grouped_df, frequency, on='CustomerID',how='inner')

# %%
grouped_df
# Out:
#       CustomerID   amount  frequency
# 0        12346.0     0.00          2
# 1        12347.0  4310.00        182
# 2        12348.0  1797.24         31
# 3        12349.0  1757.55         73
# 4        12350.0   334.40         17
# ...          ...      ...        ...
# 4367     18280.0   180.60         10
# 4368     18281.0    80.82          7
# 4369     18282.0   176.60         13
# 4370     18283.0  2094.88        756
# 4371     18287.0  1837.28         70
#
# [4372 rows x 3 columns]

# %%
#Recency (09/12/2011)
retail_df['InvoiceDate'] = pd.to_datetime(retail_df['InvoiceDate'], format ='%d-%m-%Y %H:%M')

# %%
retail_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  amount
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom   15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom   22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34

# %%
retail_df['diff'] = max(retail_df['InvoiceDate'])- retail_df['InvoiceDate']

# %%
retail_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  amount  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom   15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom   22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34
#
#                diff
# 0 373 days 04:24:00
# 1 373 days 04:24:00
# 2 373 days 04:24:00
# 3 373 days 04:24:00
# 4 373 days 04:24:00

# %%
lastPurchase = retail_df.groupby('CustomerID')['diff'].min()

# %%
lastPurchase = lastPurchase.reset_index()

# %%
grouped_df = pd.merge(grouped_df, lastPurchase, on='CustomerID',how='inner')

# %%
grouped_df.columns
# Out:
# Index(['CustomerID', 'amount', 'frequency', 'diff'], dtype='object')

# %%
grouped_df.columns = ['CustomerID', 'amount', 'frequency', 'recency']

# %%
grouped_df.head()
# Out:
#    CustomerID   amount  frequency           recency
# 0     12346.0     0.00          2 325 days 02:33:00
# 1     12347.0  4310.00        182   1 days 20:58:00
# 2     12348.0  1797.24         31  74 days 23:37:00
# 3     12349.0  1757.55         73  18 days 02:59:00
# 4     12350.0   334.40         17 309 days 20:49:00

# %%
grouped_df['recency'] =  grouped_df['recency'].dt.days

# %%
grouped_df.head()
# Out:
#    CustomerID   amount  frequency  recency
# 0     12346.0     0.00          2      325
# 1     12347.0  4310.00        182        1
# 2     12348.0  1797.24         31       74
# 3     12349.0  1757.55         73       18
# 4     12350.0   334.40         17      309

# %%
#Outlier Treatment
#Rescaling variables
#

# %%
grouped_df.amount.plot.box()
# Out:
# <AxesSubplot:>

# %%
# - Types of Outliers
# - Stastical Outliers
# - Domain Specific Outliers

# %%
#removing stattistical outliers

Q1 = grouped_df.amount.quantile(0.05)
Q3 = grouped_df.amount.quantile(0.95)

IQR = Q3-Q1
grouped_df = grouped_df[(grouped_df.amount>=Q1-1.5*IQR)& (grouped_df.amount<=Q3+1.5*IQR)]

# %%
Q1 = grouped_df.frequency.quantile(0.05)
Q3 = grouped_df.frequency.quantile(0.95)

IQR = Q3-Q1
grouped_df = grouped_df[(grouped_df.frequency>=Q1-1.5*IQR)& (grouped_df.frequency<=Q3+1.5*IQR)]

# %%
Q1 = grouped_df.recency.quantile(0.05)
Q3 = grouped_df.recency.quantile(0.95)

IQR = Q3-Q1
grouped_df = grouped_df[(grouped_df.recency>=Q1-1.5*IQR)& (grouped_df.recency<=Q3+1.5*IQR)]

# %%
grouped_df.frequency.plot.box()
# Out:
# <AxesSubplot:>

# %%
grouped_df.recency.plot.box()
# Out:
# <AxesSubplot:>

# %%
#Rescaling
rfm_df = grouped_df[['amount', 'frequency', 'recency']]

# %%
scaler = StandardScaler()
rfm_df_scaled = scaler.fit_transform(rfm_df)

# %%
rfm_df_scaled.shape
# Out:
# (4293, 3)

# %%
#rfm_df_scaled.head()

# %%
from sklearn.neighbors import NearestNeighbors
from random import sample
from numpy.random import uniform
import numpy as np
from math import isnan

def hopkins(X):
    d = X.shape[1]
    #d = len(vars) # columns
    n = len(X) # rows
    m = int(0.1 * n) 
    nbrs = NearestNeighbors(n_neighbors=1).fit(X.values)
 
    rand_X = sample(range(0, n, 1), m)
 
    ujd = []
    wjd = []
    for j in range(0, m):
        u_dist, _ = nbrs.kneighbors(uniform(np.amin(X,axis=0),np.amax(X,axis=0),d).reshape(1, -1), 2, return_distance=True)
        ujd.append(u_dist[0][1])
        w_dist, _ = nbrs.kneighbors(X.iloc[rand_X[j]].values.reshape(1, -1), 2, return_distance=True)
        wjd.append(w_dist[0][1])
 
    H = sum(ujd) / (sum(ujd) + sum(wjd))
    if isnan(H):
        print(ujd, wjd)
        H = 0
 
    return H

# %%
rfm_df_scaled = pd.DataFrame(rfm_df_scaled)

# %%
rfm_df_scaled.columns = ['amount', 'frequency', 'recency']

# %%
hopkins(rfm_df_scaled)
# Out:
# 0.9531270752435772

# %% [markdown]
# ### Modelling

# %%
kmeans = KMeans(n_clusters=4, max_iter=50)
kmeans.fit(rfm_df_scaled)
# Out:
# KMeans(max_iter=50, n_clusters=4)

# %%
kmeans.labels_
# Out:
# array([2, 1, 0, ..., 2, 0, 0])

# %%
len(kmeans.labels_)
# Out:
# 4293

# %%
range_n_clusters = [2,3,4,5,6,7,8]
ssd = []
for range in range_n_clusters:
    kmeans = KMeans(n_clusters=range, max_iter=50)
    kmeans.fit(rfm_df_scaled)
    
    ssd.append(kmeans.inertia_)

plt.plot(ssd)

# %%
range_n_clusters = [2,3,4,5,6,7,8]

for range in range_n_clusters:
    kmeans = KMeans(n_clusters=range, max_iter=50)
    kmeans.fit(rfm_df_scaled)
    
    cluster_labels = kmeans.labels_
    silhoute_avg =silhouette_score(rfm_df_scaled, cluster_labels)
    print('For n_clusters = {0}, silhoutescore is {1}'.format(range, silhoute_avg))
# Out:
# For n_clusters = 2, silhoutescore is 0.5415858652525395
# For n_clusters = 3, silhoutescore is 0.5084896296141937
# For n_clusters = 4, silhoutescore is 0.4812247940142438
# For n_clusters = 5, silhoutescore is 0.4638787576606892
# For n_clusters = 6, silhoutescore is 0.4169897163641209
# For n_clusters = 7, silhoutescore is 0.417092710912018
# For n_clusters = 8, silhoutescore is 0.40947717970268144

# %%
kmeans = KMeans(n_clusters=3, max_iter=50)
kmeans.fit(rfm_df_scaled)
# Out:
# KMeans(max_iter=50, n_clusters=3)

# %%
kmeans.labels_
# Out:
# array([2, 1, 0, ..., 2, 0, 0])

# %%
grouped_df['cluster_id'] = kmeans.labels_
grouped_df.head()
# Out:
#    CustomerID   amount  frequency  recency  cluster_id
# 0     12346.0     0.00          2      325           2
# 1     12347.0  4310.00        182        1           1
# 2     12348.0  1797.24         31       74           0
# 3     12349.0  1757.55         73       18           0
# 4     12350.0   334.40         17      309           2

# %%
sns.boxplot(x='cluster_id', y = 'amount', data = grouped_df)
# Out:
# <AxesSubplot:xlabel='cluster_id', ylabel='amount'>

# %%
sns.boxplot(x='cluster_id', y = 'recency', data = grouped_df)
# Out:
# <AxesSubplot:xlabel='cluster_id', ylabel='recency'>

# %%
sns.boxplot(x='cluster_id', y = 'frequency', data = grouped_df)
# Out:
# <AxesSubplot:xlabel='cluster_id', ylabel='frequency'>

# %% [markdown]
# ### Hierarchical

# %%
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import cut_tree

# %%
rfm_df_scaled
# Out:
#         amount  frequency   recency
# 0    -0.723738  -0.752888  2.301611
# 1     1.731617   1.042467 -0.906466
# 2     0.300128  -0.463636 -0.183658
# 3     0.277517  -0.044720 -0.738141
# 4    -0.533235  -0.603275  2.143188
# ...        ...        ...       ...
# 4288 -0.624669  -0.683068 -0.193560
# 4289 -0.620853  -0.673094  1.826341
# 4290 -0.677696  -0.703017  0.865898
# 4291 -0.623131  -0.643171 -0.847057
# 4292  0.322938  -0.074643 -0.500505
#
# [4293 rows x 3 columns]

# %%
#single linkage
mergings = linkage(rfm_df_scaled, method="single", metric="euclidean")
dendrogram(mergings)
plt.show(mergings)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-6db4d48e3c9d> in <module>
#       2 mergings = linkage(rfm_df_scaled, method="single", metric="euclidean")
#       3 dendrogram(mergings)
# ----> 4 plt.show(mergings)
#
# D:\Installations\Annaconda\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# D:\Installations\Annaconda\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      47         # only call close('all') if any to close
#      48         # close triggers gc.collect, which can be slow
# ---> 49         if close and Gcf.get_all_fig_managers():
#      50             matplotlib.pyplot.close('all')
#      51
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
mergings = linkage(rfm_df_scaled, method="complete", metric="euclidean")
dendrogram(mergings)
plt.show(mergings)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-2f5fc1a09638> in <module>
#       1 mergings = linkage(rfm_df_scaled, method="complete", metric="euclidean")
#       2 dendrogram(mergings)
# ----> 3 plt.show(mergings)
#
# D:\Installations\Annaconda\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# D:\Installations\Annaconda\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      47         # only call close('all') if any to close
#      48         # close triggers gc.collect, which can be slow
# ---> 49         if close and Gcf.get_all_fig_managers():
#      50             matplotlib.pyplot.close('all')
#      51
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
census = pd.read_excel("Main.xlsx")

# %%
census.head()
# Out:
#                   Area Name  Illiterate  Graduate & above  Total - Population  \
# 0   State - JAMMU & KASHMIR     3378518            385463            12541302
# 1  State - HIMACHAL PRADESH      963742            267936             6864602
# 2            State - PUNJAB     4886265            979525            27743338
# 3        State - CHANDIGARH      175200             91276             1055450
# 4       State - UTTARAKHAND     1929236            525301            10086292
#
#    Percentage Illiterate  Percentage Graduate & above
# 0              26.939133                     3.073549
# 1              14.039299                     3.903154
# 2              17.612390                     3.530667
# 3              16.599555                     8.648065
# 4              19.127307                     5.208069

# %%
rmf = census[['Percentage Illiterate', 'Percentage Graduate & above']]

# %%
scaler = StandardScaler()

# %%
rmf_scaled = scaler.fit_transform(rmf)

# %%
mergings = linkage(rmf_scaled, method="complete", metric="euclidean")
dendrogram(mergings)
plt.show(mergings)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-3c67c36105cc> in <module>
#       1 mergings = linkage(rmf_scaled, method="complete", metric="euclidean")
#       2 dendrogram(mergings)
# ----> 3 plt.show(mergings)
#
# D:\Installations\Annaconda\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# D:\Installations\Annaconda\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      47         # only call close('all') if any to close
#      48         # close triggers gc.collect, which can be slow
# ---> 49         if close and Gcf.get_all_fig_managers():
#      50             matplotlib.pyplot.close('all')
#      51
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
mergings = linkage(rmf_scaled, method="single", metric="euclidean")
dendrogram(mergings)
plt.show(mergings)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-a04450f95602> in <module>
#       1 mergings = linkage(rmf_scaled, method="single", metric="euclidean")
#       2 dendrogram(mergings)
# ----> 3 plt.show(mergings)
#
# D:\Installations\Annaconda\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# D:\Installations\Annaconda\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      47         # only call close('all') if any to close
#      48         # close triggers gc.collect, which can be slow
# ---> 49         if close and Gcf.get_all_fig_managers():
#      50             matplotlib.pyplot.close('all')
#      51
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
mergings = linkage(rmf_scaled, method="average", metric="euclidean")
dendrogram(mergings)
plt.show(mergings)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-2b2807032a64> in <module>
#       1 mergings = linkage(rmf_scaled, method="average", metric="euclidean")
#       2 dendrogram(mergings)
# ----> 3 plt.show(mergings)
#
# D:\Installations\Annaconda\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# D:\Installations\Annaconda\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      47         # only call close('all') if any to close
#      48         # close triggers gc.collect, which can be slow
# ---> 49         if close and Gcf.get_all_fig_managers():
#      50             matplotlib.pyplot.close('all')
#      51
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
cricket = pd.read_csv("Cricket.csv")
cricket.head()
# Out:
#                         Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0         SR Tendulkar�(INDIA)  1989-2012  463   452  41  18426  200*  44.83
# 1  KC Sangakkara�(Asia/ICC/SL)  2000-2015  404   380  41  14234   169  41.98
# 2         RT Ponting�(AUS/ICC)  1995-2012  375   365  39  13704   164  42.03
# 3      ST Jayasuriya�(Asia/SL)  1989-2011  445   433  18  13430   189  32.36
# 4   DPMD Jayawardene�(Asia/SL)  1998-2015  448   418  39  12650   144  33.37
#
#       BF     SR  100  50   0
# 0  21367  86.23   49  96  20
# 1  18048  78.86   25  93  15
# 2  17046  80.39   30  82  20
# 3  14725  91.20   28  68  34
# 4  16020  78.96   19  77  28

# %%
cluster_df = cricket[['SR', 'Ave']]

scaler = StandardScaler()
scaled_df = scaler.fit_transform(cluster_df)

# %%
mergings = linkage(scaled_df, method="complete", metric="euclidean")
dendrogram(mergings)
plt.show(mergings)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-359ddda88df8> in <module>
#       1 mergings = linkage(scaled_df, method="complete", metric="euclidean")
#       2 dendrogram(mergings)
# ----> 3 plt.show(mergings)
#
# D:\Installations\Annaconda\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# D:\Installations\Annaconda\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      47         # only call close('all') if any to close
#      48         # close triggers gc.collect, which can be slow
# ---> 49         if close and Gcf.get_all_fig_managers():
#      50             matplotlib.pyplot.close('all')
#      51
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
labels = cut_tree(Z=mergings,n_clusters=4 )

# %%
labels.shape
# Out:
# (79, 1)

# %%
labels = labels.reshape(-1,)

# %%
cricket['cluster'] = labels

# %%
pd.set_option('max_rows', 100)
cricket.sort_values('cluster')
# Out:
#                           Player       Span  Mat  Inns  NO   Runs    HS  \
# 0           SR Tendulkar�(INDIA)  1989-2012  463   452  41  18426  200*
# 32           Javed Miandad�(PAK)  1975-1996  233   218  41   7381  119*
# 37             GC Smith�(Afr/SA)  2002-2013  197   194  10   6989   141
# 77               A Symonds�(AUS)  1998-2009  198   161  33   5088   156
# 42             IVA Richards�(WI)  1975-1991  187   167  24   6721  189*
# 46              LRPL Taylor�(NZ)  2006-2017  190   176  29   6486  131*
# 49           ML Hayden�(AUS/ICC)  1993-2008  161   155  15   6133  181*
# 51                DM Jones�(AUS)  1984-1994  164   161  25   6068   145
# 52                 DC Boon�(AUS)  1984-1995  181   177  16   5964   122
